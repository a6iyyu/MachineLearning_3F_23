# %% [markdown]
# ## **Bagian 1**

# %%
# %pip install neurokit2 pyprep scikit-learn scipy wandb
# Out:
# Requirement already satisfied: neurokit2 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (0.2.12)
# Requirement already satisfied: pyprep in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (0.5.0)
# Requirement already satisfied: scikit-learn in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (1.7.1)
# Requirement already satisfied: scipy in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (1.16.1)
# Requirement already satisfied: wandb in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (0.21.1)
# Requirement already satisfied: requests in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from neurokit2) (2.32.5)
# Requirement already satisfied: numpy in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from neurokit2) (2.3.2)
# Requirement already satisfied: pandas in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from neurokit2) (2.3.2)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from neurokit2) (3.10.5)
# Requirement already satisfied: PyWavelets>=1.4.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from neurokit2) (1.9.0)
# Requirement already satisfied: mne>=1.3.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pyprep) (1.10.1)
# Requirement already satisfied: psutil>=5.4.3 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pyprep) (7.0.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (6.32.0)
# Requirement already satisfied: pydantic<3 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (2.11.7)
# Requirement already satisfied: pyyaml in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (6.0.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (2.35.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from requests->neurokit2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from requests->neurokit2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from requests->neurokit2) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: decorator in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from mne>=1.3.0->pyprep) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from mne>=1.3.0->pyprep) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from mne>=1.3.0->pyprep) (0.4)
# Requirement already satisfied: pooch>=1.5 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from mne>=1.3.0->pyprep) (1.8.2)
# Requirement already satisfied: tqdm in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from mne>=1.3.0->pyprep) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from jinja2->mne>=1.3.0->pyprep) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\berkah\documents\kuliah\semester-5\ml\venv\lib\site-packages (from pandas->neurokit2) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Buat _file notebook_ dengan nama **TG1_NIM_NAMA.ipynb**. Contoh: **JS1_2341720115_Rafi Abiyyu Airlangga.ipynb**.
#
# 2. Lakukan instalasi library berikut pada notebook,
#
#    ```python
#    PyPREP
#    Scipy
#    wandb
#    pyECG
#    ```
#
# 3. Jelaskan kegunakan masing-masing _library_ tersebut.
#
#    Jawaban:
#
#    - PyPREP
#
#      <u>Digunakan untuk _preprocessing_ sinyal EEG (_Electroencephalogram_). _Library_ ini membantu membersihkan sinyal dari artefak (_noise_ seperti kedipan mata, gerakan otot, atau interferensi listrik) sehingga data lebih siap untuk dianalisis.</u>
#
#    - SciPy
#
#      <u>_Library_ ilmiah di Python yang berisi fungsi-fungsi matematika, statistik, dan pengolahan sinyal. Berguna untuk operasi numerik, optimisasi, _filtering_ sinyal, hingga pemrosesan data biomedis seperti ECG atau EEG.</u>
#
#    - wandb (Weights & Biases)
#
#      <u>Alat untuk eksperimen _machine learning tracking_. Membantu mencatat hasil _training model_, memvisualisasikan metrik (akurasi, _loss_), menyimpan konfigurasi _hyperparameter_, dan mempermudah kolaborasi tim riset.</u>
#
#    - pyECG
#
#      <u>_Library_ untuk analisis sinyal ECG (Electrocardiogram). Biasanya digunakan untuk mendeteksi _R-peaks_, menghitung _heart rate_, atau mengekstraksi fitur sinyal jantung. Walaupun agak lawas (dependensi _sklearn_), masih berguna untuk eksperimen pemrosesan ECG.</u>
#
# ## **Bagian 2**
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
#    Jawaban:
#
#    - Deepfake tanpa izin → Membuat video palsu orang terkenal untuk tujuan penipuan, pornografi non-konsensual, atau propaganda politik.
#
#    - Plagiarisme akademik → Menggunakan AI untuk menulis tugas, skripsi, atau jurnal tanpa atribusi, lalu mengklaim hasilnya sebagai karya pribadi.
#
#    - AI untuk kejahatan siber → Memanfaatkan AI untuk phishing otomatis, cracking password, atau menyebarkan malware.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
#    Jawaban:
#
#    **Dampak**
#
#    - _Training model_ AI besar (seperti GPT, BERT) membutuhkan energi komputasi sangat besar, menghasilkan jejak karbon yang signifikan.
#    - _Data center_ AI mengonsumsi listrik dan air dalam jumlah besar untuk pendinginan, sehingga meningkatkan emisi karbon.
#
#    **Cara mengatasi**
#
#    - Efisiensi model: Menggunakan teknik _model compression_, _knowledge distillation_, dan _transfer learning_ agar tidak perlu melatih dari nol.
#    - _Green data center_: Memakai energi terbarukan (matahari, angin) untuk operasional _data center_.
#    - _AI for environment_: Menggunakan AI untuk memantau energi, cuaca, atau optimasi sistem listrik agar lebih efisien.
